# %%
import pandas as pd
import pymongo

df = pd.read_csv('student_depression_dataset.csv')
df.head(2)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0    '5-6 hours'
# 1            0.0  5.90                 5.0               0.0    '5-6 hours'
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# 1       Moderate      BSc                                    No
#
#    Work/Study Hours Financial Stress Family History of Mental Illness  \
# 0               3.0              1.0                               No
# 1               3.0              2.0                              Yes
#
#    Depression
# 0           1
# 1           0

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://iamhimanshu12goel:G5e2VQpaGlF0ou54@cluster0.oyrchd2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)

# %%
df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  id  Gender   Age           City Profession  \
# 0  680662e0a4bf8814f4bc34db   2    Male  33.0  Visakhapatnam    Student
# 1  680662e0a4bf8814f4bc34dc   8  Female  24.0      Bangalore    Student
#
#    Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0                5.0            0.0  8.97                 2.0
# 1                2.0            0.0  5.90                 5.0
#
#    Job Satisfaction Sleep Duration Dietary Habits   Degree  \
# 0               0.0    '5-6 hours'        Healthy  B.Pharm
# 1               0.0    '5-6 hours'       Moderate      BSc
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
